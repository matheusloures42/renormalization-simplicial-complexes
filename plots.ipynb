# %%
import networkx as nx
import numpy as np
import pandas as pd  
import os
import glob
from utils import *
from plot import *
from renormalizer import *
from kuramoto_plot import *
from simplicial_complexes import *

# %%
Gair0=nx.read_edgelist('Data/air0_edgelist.txt')
Gair1=nx.read_edgelist('Data/air1_edgelist.txt')
Gair2=nx.read_edgelist('Data/air2_edgelist.txt')
Gair3=nx.read_edgelist('Data/air3_edgelist.txt')

# %%
Gcel0=nx.read_edgelist('Data/cel0_edgelist.txt')
Gcel1=nx.read_edgelist('Data/cel1_edgelist.txt')
Gcel2=nx.read_edgelist('Data/cel2_edgelist.txt')
Gcel3=nx.read_edgelist('Data/cel3_edgelist.txt')

# %%
Gus0=nx.read_edgelist('Data/us_edgelist.txt')
Gus1=nx.read_edgelist('Data/us1_edgelist.txt')
Gus2=nx.read_edgelist('Data/us2_edgelist.txt')
Gus3=nx.read_edgelist('Data/us3_edgelist.txt')

# %%
m1_0=nx.read_edgelist('Data/m1_edgelist.txt')
m1_1=nx.read_edgelist('Data/m1_1_edgelist.txt')
m1_2=nx.read_edgelist('Data/m1_2_edgelist.txt')
m1_3=nx.read_edgelist('Data/m1_3_edgelist.txt')

# %%
m5_0=nx.read_edgelist('Data/m5_edgelist.txt')
m5_1=nx.read_edgelist('Data/m5_1_edgelist.txt')
m5_2=nx.read_edgelist('Data/m5_2_edgelist.txt')
m5_3=nx.read_edgelist('Data/m5_3_edgelist.txt')

# %%
m10_0=nx.read_edgelist('Data/m10_edgelist.txt')
m10_1=nx.read_edgelist('Data/m10_1_edgelist.txt')
m10_2=nx.read_edgelist('Data/m10_2_edgelist.txt')
m10_3=nx.read_edgelist('Data/m10_3_edgelist.txt')

# %%
p005=nx.read_edgelist('Data/p005_edgelist.txt')
p005_1=nx.read_edgelist('Data/p005_1_edgelist.txt')
p005_2=nx.read_edgelist('Data/p005_2_edgelist.txt')
p005_3=nx.read_edgelist('Data/p005_3_edgelist.txt')

# %%
p01=nx.read_edgelist('Data/p01_edgelist.txt')
p01_1=nx.read_edgelist('Data/p01_1_edgelist.txt')
p01_2=nx.read_edgelist('Data/p01_2_edgelist.txt')
p01_3=nx.read_edgelist('Data/p01_3_edgelist.txt')

# %%
p02=nx.read_edgelist('Data/p02_edgelist.txt')
p02_1=nx.read_edgelist('Data/p02_1_edgelist.txt')
p02_2=nx.read_edgelist('Data/p02_2_edgelist.txt')
p02_3=nx.read_edgelist('Data/p02_3_edgelist.txt')

# %%
fig,axs=plt.subplots(3,3,figsize=(25, 25))

plt.subplot(3,3,1)

plt.title('(a) C.elegans')

plot_ccdf(Gcel0,lb='l=0')
plot_ccdf(Gcel1,lb='l=1')
plot_ccdf(Gcel2,lb='l=2')
plot_ccdf(Gcel3,lb='l=3')

 

plt.subplot(3,3,2)

plt.title('(b) Airport')

plot_ccdf(Gair0,lb='l=0')
plot_ccdf(Gair1,lb='l=1')
plot_ccdf(Gair2,lb='l=2')
plot_ccdf(Gair3,lb='l=3')



plt.subplot(3,3,3)

plt.title('(c) US powergrid')

plot_ccdf(Gus0,lb='l=0')
plot_ccdf(Gus1,lb='l=1')
plot_ccdf(Gus2,lb='l=2')
plot_ccdf(Gus3,lb='l=3')


plt.subplot(3,3,4)

clustering_per_kl(Gcel0,lb='l=0')
clustering_per_kl(Gcel1,lb='l=1')
clustering_per_kl(Gcel2,lb='l=2')
clustering_per_kl(Gcel3,lb='l=3')


plt.subplot(3,3,5)

clustering_per_kl(Gair0,lb='l=0')
clustering_per_kl(Gair1,lb='l=1')
clustering_per_kl(Gair2,lb='l=2')
clustering_per_kl(Gair3,lb='l=3')


plt.subplot(3,3,6)

clustering_per_kl(Gus0,lb='l=0')
clustering_per_kl(Gus1,lb='l=1')
clustering_per_kl(Gus2,lb='l=2')
clustering_per_kl(Gus3,lb='l=3')

plt.subplot(3,3,7)

average_neighbor_degree_x_kl(Gcel0,lb='l=0')
average_neighbor_degree_x_kl(Gcel1,lb='l=1')
average_neighbor_degree_x_kl(Gcel2,lb='l=2')
average_neighbor_degree_x_kl(Gcel3,lb='l=3')


plt.subplot(3,3,8)

average_neighbor_degree_x_kl(Gair0,lb='l=0')
average_neighbor_degree_x_kl(Gair1,lb='l=1')
average_neighbor_degree_x_kl(Gair2,lb='l=2')
average_neighbor_degree_x_kl(Gair3,lb='l=3')


plt.subplot(3,3,9)

average_neighbor_degree_x_kl(Gus0,lb='l=0')
average_neighbor_degree_x_kl(Gus1,lb='l=1')
average_neighbor_degree_x_kl(Gus2,lb='l=2')
average_neighbor_degree_x_kl(Gus3,lb='l=3')

#for ax in fig.get_axes():
 #   ax.label_outer()

# %%
fig,axs=plt.subplots(2,3,figsize=(20, 20))


plt.subplot(2,3,1)
plt.title('(a) C.elegans')
clustering_per_kl_c0(Gcel0,lb='l=0')
clustering_per_kl_c0(Gcel1,lb='l=1')
clustering_per_kl_c0(Gcel2,lb='l=2')
clustering_per_kl_c0(Gcel3,lb='l=3')


plt.subplot(2,3,2)
plt.title('(b) Airport')
clustering_per_kl_c0(Gair0,lb='l=0')
clustering_per_kl_c0(Gair1,lb='l=1')
clustering_per_kl_c0(Gair2,lb='l=2')
clustering_per_kl_c0(Gair3,lb='l=3')

plt.subplot(2,3,3)
plt.title('(c) US powergrid')
clustering_per_kl_c0(Gus0,lb='l=0')
clustering_per_kl_c0(Gus1,lb='l=1')
clustering_per_kl_c0(Gus2,lb='l=2')
clustering_per_kl_c0(Gus3,lb='l=3')


plt.subplot(2,3,4)

plot_all_dist(Gcel0,lb='l=0')
plot_all_dist(Gcel1,lb='l=1')
plot_all_dist(Gcel2,lb='l=2')
plot_all_dist(Gcel3,lb='l=3')


plt.subplot(2,3,5)

plot_all_dist(Gair0,lb='l=0')
plot_all_dist(Gair1,lb='l=1')
plot_all_dist(Gair2,lb='l=2')
plot_all_dist(Gair3,lb='l=3')

plt.subplot(2,3,6)

plot_all_dist(Gus0,lb='l=0')
plot_all_dist(Gus1,lb='l=1')
plot_all_dist(Gus2,lb='l=2')
plot_all_dist(Gus3,lb='l=3')

# %%
print(nx.average_shortest_path_length(Gair0))
print(nx.average_shortest_path_length(Gair1))
print(nx.average_shortest_path_length(Gair2))
print(nx.average_shortest_path_length(Gair3))
# Out:
# 4.097139443251163
# 3.609684721835132
# 3.13361449937666
# 2.658356794720431

# %%
print(nx.average_shortest_path_length(Gus0))
print(nx.average_shortest_path_length(Gus1))
print(nx.average_shortest_path_length(Gus2))
print(nx.average_shortest_path_length(Gus3))
# Out:
# 18.989185424445708
# 13.458589926548775
# 10.528896924911233
# 7.443648932878056

# %%
fig,axs=plt.subplots(3,3,figsize=(25, 25))

plt.subplot(3,3,1)

plt.title('(a) m=1')

plot_ccdf(m1_0,lb='l=0')
plot_ccdf(m1_1,lb='l=1')
plot_ccdf(m1_2,lb='l=2')
plot_ccdf(m1_3,lb='l=3')

 

plt.subplot(3,3,2)

plt.title('(b) m=5')

plot_ccdf(m5_0,lb='l=0')
plot_ccdf(m5_1,lb='l=1')
plot_ccdf(m5_2,lb='l=2')
plot_ccdf(m5_3,lb='l=3')



plt.subplot(3,3,3)

plt.title('(c) m=10')

plot_ccdf(m10_0,lb='l=0')
plot_ccdf(m10_1,lb='l=1')
plot_ccdf(m10_2,lb='l=2')
plot_ccdf(m10_3,lb='l=3')


plt.subplot(3,3,4)

clustering_per_kl(m1_0,lb='l=0')
clustering_per_kl(m1_1,lb='l=1')
clustering_per_kl(m1_2,lb='l=2')
clustering_per_kl(m1_3,lb='l=3')


plt.subplot(3,3,5)

clustering_per_kl(m5_0,lb='l=0')
clustering_per_kl(m5_1,lb='l=1')
clustering_per_kl(m5_2,lb='l=2')
clustering_per_kl(m5_3,lb='l=3')


plt.subplot(3,3,6)

clustering_per_kl(m10_0,lb='l=0')
clustering_per_kl(m10_1,lb='l=1')
clustering_per_kl(m10_2,lb='l=2')
clustering_per_kl(m10_3,lb='l=3')

plt.subplot(3,3,7)

average_neighbor_degree_x_kl(m1_0,lb='l=0')
average_neighbor_degree_x_kl(m1_1,lb='l=1')
average_neighbor_degree_x_kl(m1_2,lb='l=2')
average_neighbor_degree_x_kl(m1_3,lb='l=3')


plt.subplot(3,3,8)

average_neighbor_degree_x_kl(m5_0,lb='l=0')
average_neighbor_degree_x_kl(m5_1,lb='l=1')
average_neighbor_degree_x_kl(m5_2,lb='l=2')
average_neighbor_degree_x_kl(m5_3,lb='l=3')


plt.subplot(3,3,9)

average_neighbor_degree_x_kl(m10_0,lb='l=0')
average_neighbor_degree_x_kl(m10_1,lb='l=1')
average_neighbor_degree_x_kl(m10_2,lb='l=2')
average_neighbor_degree_x_kl(m10_3,lb='l=3')

#for ax in fig.get_axes():
 #   ax.label_outer()
# Out:
# C:\Users\Costelinha\Documents\Codes\renormalization-simplicial-complexes\plot.py:369: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.yscale('log')

# %%
fig,axs=plt.subplots(2,3,figsize=(20, 20))


plt.subplot(2,3,1)
plt.title('(a) m=1')
clustering_per_kl_c0(m1_0,lb='l=0')
clustering_per_kl_c0(m1_1,lb='l=1')
clustering_per_kl_c0(m1_2,lb='l=2')
clustering_per_kl_c0(m1_3,lb='l=3')


plt.subplot(2,3,2)
plt.title('(b) m=5')
clustering_per_kl_c0(m5_0,lb='l=0')
clustering_per_kl_c0(m5_1,lb='l=1')
clustering_per_kl_c0(m5_2,lb='l=2')
clustering_per_kl_c0(m5_3,lb='l=3')

plt.subplot(2,3,3)
plt.title('(c) m=10')
clustering_per_kl_c0(m10_0,lb='l=0')
clustering_per_kl_c0(m10_1,lb='l=1')
clustering_per_kl_c0(m10_2,lb='l=2')
clustering_per_kl_c0(m10_3,lb='l=3')


plt.subplot(2,3,4)

plot_all_dist(m1_0,lb='l=0')
plot_all_dist(m1_1,lb='l=1')
plot_all_dist(m1_2,lb='l=2')
plot_all_dist(m1_3,lb='l=3')


plt.subplot(2,3,5)

plot_all_dist(m5_0,lb='l=0')
plot_all_dist(m5_1,lb='l=1')
plot_all_dist(m5_2,lb='l=2')
plot_all_dist(m5_3,lb='l=3')

plt.subplot(2,3,6)

plot_all_dist(m10_0,lb='l=0')
plot_all_dist(m10_1,lb='l=1')
plot_all_dist(m10_2,lb='l=2')
plot_all_dist(m10_3,lb='l=3')

# %%
fig,axs=plt.subplots(3,3,figsize=(25, 25))

plt.subplot(3,3,1)

plt.title('(a) p=0.005')

plot_ccdf(p005,lb='l=0')
plot_ccdf(p005_1,lb='l=1')
plot_ccdf(p005_2,lb='l=2')
plot_ccdf(p005_3,lb='l=3')

 

plt.subplot(3,3,2)

plt.title('(b) p=0.01')

plot_ccdf(p01,lb='l=0')
plot_ccdf(p01_1,lb='l=1')
plot_ccdf(p01_2,lb='l=2')
plot_ccdf(p01_3,lb='l=3')



plt.subplot(3,3,3)

plt.title('(c) p=0.02')

plot_ccdf(p02,lb='l=0')
plot_ccdf(p02_1,lb='l=1')
plot_ccdf(p02_2,lb='l=2')
plot_ccdf(p02_3,lb='l=3')


plt.subplot(3,3,4)

clustering_per_kl(p005,lb='l=0')
clustering_per_kl(p005_1,lb='l=1')
clustering_per_kl(p005_2,lb='l=2')
clustering_per_kl(p005_3,lb='l=3')


plt.subplot(3,3,5)

clustering_per_kl(p01,lb='l=0')
clustering_per_kl(p01_1,lb='l=1')
clustering_per_kl(p01_2,lb='l=2')
clustering_per_kl(p01_3,lb='l=3')


plt.subplot(3,3,6)

clustering_per_kl(p02,lb='l=0')
clustering_per_kl(p02_1,lb='l=1')
clustering_per_kl(p02_2,lb='l=2')
clustering_per_kl(p02_3,lb='l=3')

plt.subplot(3,3,7)

average_neighbor_degree_x_kl(p005,lb='l=0')
average_neighbor_degree_x_kl(p005_1,lb='l=1')
average_neighbor_degree_x_kl(p005_2,lb='l=2')
average_neighbor_degree_x_kl(p005_3,lb='l=3')


plt.subplot(3,3,8)

average_neighbor_degree_x_kl(p01,lb='l=0')
average_neighbor_degree_x_kl(p01_1,lb='l=1')
average_neighbor_degree_x_kl(p01_2,lb='l=2')
average_neighbor_degree_x_kl(p01_3,lb='l=3')


plt.subplot(3,3,9)

average_neighbor_degree_x_kl(p02,lb='l=0')
average_neighbor_degree_x_kl(p02_1,lb='l=1')
average_neighbor_degree_x_kl(p02_2,lb='l=2')
average_neighbor_degree_x_kl(p02_3,lb='l=3')

#for ax in fig.get_axes():
 #   ax.label_outer()

# %%
fig,axs=plt.subplots(2,3,figsize=(20, 20))


plt.subplot(2,3,1)
plt.title('(a) p=0.005')
clustering_per_kl_c0(p005,lb='l=0')
clustering_per_kl_c0(p005_1,lb='l=1')
clustering_per_kl_c0(p005_2,lb='l=2')
clustering_per_kl_c0(p005_3,lb='l=3')


plt.subplot(2,3,2)
plt.title('(b) p=0.01')
clustering_per_kl_c0(p01,lb='l=0')
clustering_per_kl_c0(p01_1,lb='l=1')
clustering_per_kl_c0(p01_2,lb='l=2')
clustering_per_kl_c0(p01_3,lb='l=3')

plt.subplot(2,3,3)
plt.title('(c) p=0.02')
clustering_per_kl_c0(p02,lb='l=0')
clustering_per_kl_c0(p02_1,lb='l=1')
clustering_per_kl_c0(p02_2,lb='l=2')
clustering_per_kl_c0(p02_3,lb='l=3')


plt.subplot(2,3,4)

plot_all_dist(p005,lb='l=0')
plot_all_dist(p005_1,lb='l=1')
plot_all_dist(p005_2,lb='l=2')
plot_all_dist(p005_3,lb='l=3')


plt.subplot(2,3,5)

plot_all_dist(p01,lb='l=0')
plot_all_dist(p01_1,lb='l=1')
plot_all_dist(p01_2,lb='l=2')
plot_all_dist(p01_3,lb='l=3')

plt.subplot(2,3,6)

plot_all_dist(p02,lb='l=0')
plot_all_dist(p02_1,lb='l=1')
plot_all_dist(p02_2,lb='l=2')
plot_all_dist(p02_3,lb='l=3')

# %%
print(average_degree_square(Gcel0)/Average_degree(Gcel0))
print(average_degree_square(Gcel1)/Average_degree(Gcel1))
print(average_degree_square(Gcel2)/Average_degree(Gcel2))
print(average_degree_square(Gcel3)/Average_degree(Gcel3))
# Out:
# 25.959388646288208
# 29.26492537313433
# 27.9501822600243
# 21.14114114114114

# %%
print(average_degree_square(Gair0)/Average_degree(Gair0))
print(average_degree_square(Gair1)/Average_degree(Gair1))
print(average_degree_square(Gair2)/Average_degree(Gair2))
print(average_degree_square(Gair3)/Average_degree(Gair3))
# Out:
# 55.839565356343876
# 56.828604031951315
# 53.2407429598562
# 45.72241992882562

# %%
print(average_degree_square(Gus0)/Average_degree(Gus0))
print(average_degree_square(Gus1)/Average_degree(Gus1))
print(average_degree_square(Gus2)/Average_degree(Gus2))
print(average_degree_square(Gus3)/Average_degree(Gus3))
# Out:
# 3.8712465878070974
# 5.561016949152543
# 6.292795389048992
# 6.993168681029953

# %%
fig,axs=plt.subplots(4,2,figsize=(20, 20))

plt.subplot(4,2,1)

plt.title('(a) E.R. p=0.01')

plot_ccdf(p01,lb='l=0')
plot_ccdf(p01_1,lb='l=1')
plot_ccdf(p01_2,lb='l=2')
plot_ccdf(p01_3,lb='l=3')

plt.subplot(4,2,2)

plt.title('(b) B.A. m=5')

plot_ccdf(m5_0,lb='l=0')
plot_ccdf(m5_1,lb='l=1')
plot_ccdf(m5_2,lb='l=2')
plot_ccdf(m5_3,lb='l=3')

plt.subplot(4,2,3)


clustering_per_kl(p01,lb='l=0')
clustering_per_kl(p01_1,lb='l=1')
clustering_per_kl(p01_2,lb='l=2')
clustering_per_kl(p01_3,lb='l=3')
plt.xlim(left=10**(-1),right=10)



plt.subplot(4,2,4)



clustering_per_kl(m5_0,lb='l=0')
clustering_per_kl(m5_1,lb='l=1')
clustering_per_kl(m5_2,lb='l=2')
clustering_per_kl(m5_3,lb='l=3')
plt.xlim(left=10**(-1),right=10)


plt.subplot(4,2,5)

clustering_per_kl_c0(p01,lb='l=0')
clustering_per_kl_c0(p01_1,lb='l=1')
clustering_per_kl_c0(p01_2,lb='l=2')
clustering_per_kl_c0(p01_3,lb='l=3')

plt.xlim(left=10**(-1),right=10)

plt.subplot(4,2,6)

clustering_per_kl_c0(m5_0,lb='l=0')
clustering_per_kl_c0(m5_1,lb='l=1')
clustering_per_kl_c0(m5_2,lb='l=2')
clustering_per_kl_c0(m5_3,lb='l=3')

plt.xlim(left=10**(-1),right=10)


plt.subplot(4,2,7)

average_neighbor_degree_x_kl(p01,lb='l=0')
average_neighbor_degree_x_kl(p01_1,lb='l=1')
average_neighbor_degree_x_kl(p01_2,lb='l=2')
average_neighbor_degree_x_kl(p01_3,lb='l=3')


plt.subplot(4,2,8)

average_neighbor_degree_x_kl(m5_0,lb='l=0')
average_neighbor_degree_x_kl(m5_1,lb='l=1')
average_neighbor_degree_x_kl(m5_2,lb='l=2')
average_neighbor_degree_x_kl(m5_3,lb='l=3')

# %%
fig,axs=plt.subplots(4,3,figsize=(27, 27))

plt.subplot(4,3,1)

plt.title('(a) C.elegans')

plot_ccdf(Gcel0,lb='l=0')
plot_ccdf(Gcel1,lb='l=1')
plot_ccdf(Gcel2,lb='l=2')
plot_ccdf(Gcel3,lb='l=3')

 

plt.subplot(4,3,2)

plt.title('(b) Airport')

plot_ccdf(Gair0,lb='l=0')
plot_ccdf(Gair1,lb='l=1')
plot_ccdf(Gair2,lb='l=2')
plot_ccdf(Gair3,lb='l=3')



plt.subplot(4,3,3)

plt.title('(c) US powergrid')

plot_ccdf(Gus0,lb='l=0')
plot_ccdf(Gus1,lb='l=1')
plot_ccdf(Gus2,lb='l=2')
plot_ccdf(Gus3,lb='l=3')


plt.subplot(4,3,4)

clustering_per_kl(Gcel0,lb='l=0')
clustering_per_kl(Gcel1,lb='l=1')
clustering_per_kl(Gcel2,lb='l=2')
clustering_per_kl(Gcel3,lb='l=3')

plt.xlim(left=10**(-2),right=10)

plt.subplot(4,3,5)

clustering_per_kl(Gair0,lb='l=0')
clustering_per_kl(Gair1,lb='l=1')
clustering_per_kl(Gair2,lb='l=2')
clustering_per_kl(Gair3,lb='l=3')


plt.subplot(4,3,6)

clustering_per_kl(Gus0,lb='l=0')
clustering_per_kl(Gus1,lb='l=1')
clustering_per_kl(Gus2,lb='l=2')
clustering_per_kl(Gus3,lb='l=3')

plt.xlim(left=10**(-1),right=10**2)



plt.subplot(4,3,7)

clustering_per_kl_c0(Gcel0,lb='l=0')
clustering_per_kl_c0(Gcel1,lb='l=1')
clustering_per_kl_c0(Gcel2,lb='l=2')
clustering_per_kl_c0(Gcel3,lb='l=3')

plt.xlim(left=10**(-2),right=10)

plt.subplot(4,3,8)

clustering_per_kl_c0(Gair0,lb='l=0')
clustering_per_kl_c0(Gair1,lb='l=1')
clustering_per_kl_c0(Gair2,lb='l=2')
clustering_per_kl_c0(Gair3,lb='l=3')


plt.subplot(4,3,9)

clustering_per_kl_c0(Gus0,lb='l=0')
clustering_per_kl_c0(Gus1,lb='l=1')
clustering_per_kl_c0(Gus2,lb='l=2')
clustering_per_kl_c0(Gus3,lb='l=3')

plt.xlim(left=10**(-1),right=10**2)
plt.ylim(bottom=1, top=10**3)

plt.subplot(4,3,10)

average_neighbor_degree_x_kl(Gcel0,lb='l=0')
average_neighbor_degree_x_kl(Gcel1,lb='l=1')
average_neighbor_degree_x_kl(Gcel2,lb='l=2')
average_neighbor_degree_x_kl(Gcel3,lb='l=3')

plt.xlim(left=10**(-2),right=10)

plt.subplot(4,3,11)

average_neighbor_degree_x_kl(Gair0,lb='l=0')
average_neighbor_degree_x_kl(Gair1,lb='l=1')
average_neighbor_degree_x_kl(Gair2,lb='l=2')
average_neighbor_degree_x_kl(Gair3,lb='l=3')

plt.xlim(left=10**(-2),right=10**2)

plt.subplot(4,3,12)

average_neighbor_degree_x_kl(Gus0,lb='l=0')
average_neighbor_degree_x_kl(Gus1,lb='l=1')
average_neighbor_degree_x_kl(Gus2,lb='l=2')
average_neighbor_degree_x_kl(Gus3,lb='l=3')

plt.xlim(left=10**(-1),right=10**2)

#for ax in fig.get_axes():
 #   ax.label_outer()
# Out:
# (0.1, 100)

# %%
fig,axs=plt.subplots(1,3,figsize=(30, 30))

plt.subplot(4,3,1)

plt.title('(a) C.elegans')

average_GD(Gcel0,lb='l=0')
average_GD(Gcel1,lb='l=1')
average_GD(Gcel2,lb='l=2')
average_GD(Gcel3,lb='l=3')

 

plt.subplot(4,3,2)

plt.title('(b) Airport')

average_GD(Gair0,lb='l=0')
average_GD(Gair1,lb='l=1')
average_GD(Gair2,lb='l=2')
average_GD(Gair3,lb='l=3')



plt.subplot(4,3,3)

plt.title('(c) US powergrid')

average_GD(Gus0,lb='l=0')
average_GD(Gus1,lb='l=1')
average_GD(Gus2,lb='l=2')
average_GD(Gus3,lb='l=3')

# %%
fig,axs=plt.subplots(1,3,figsize=(30, 30))

plt.subplot(4,3,1)

plt.title('(a) C.elegans')

average_GD_x_kl(Gcel0,lb='l=0')
average_GD_x_kl(Gcel1,lb='l=1')
average_GD_x_kl(Gcel2,lb='l=2')
average_GD_x_kl(Gcel3,lb='l=3')

 

plt.subplot(4,3,2)

plt.title('(b) Airport')

average_GD_x_kl(Gair0,lb='l=0')
average_GD_x_kl(Gair1,lb='l=1')
average_GD_x_kl(Gair2,lb='l=2')
average_GD_x_kl(Gair3,lb='l=3')



plt.subplot(4,3,3)

plt.title('(c) US powergrid')

average_GD_x_kl(Gus0,lb='l=0')
average_GD_x_kl(Gus1,lb='l=1')
average_GD_x_kl(Gus2,lb='l=2')
average_GD_x_kl(Gus3,lb='l=3')

# %%
fig,axs=plt.subplots(4,3,figsize=(20, 20))

plt.subplot(4,3,1)

plt.title('(a) C.elegans')

heat_map_covariance(Gcel0)



plt.subplot(4,3,2)

plt.title('(b) Airport')

heat_map_covariance(Gair0)



plt.subplot(4,3,3)

plt.title('(c) US powergrid')

heat_map_covariance(Gus0)


plt.subplot(4,3,4)

heat_map_covariance(Gcel1)



plt.subplot(4,3,5)

heat_map_covariance(Gair1)


plt.subplot(4,3,6)

heat_map_covariance(Gus1)


plt.subplot(4,3,7)

heat_map_covariance(Gcel2)


plt.subplot(4,3,8)

heat_map_covariance(Gair2)


plt.subplot(4,3,9)

heat_map_covariance(Gus2)

plt.subplot(4,3,10)

heat_map_covariance(Gcel3)


plt.subplot(4,3,11)

heat_map_covariance(Gair3)

plt.subplot(4,3,12)

heat_map_covariance(Gus3)

# %%
fig,axs=plt.subplots(4,3,figsize=(20, 20))

plt.subplot(4,3,1)

plt.title('(a) C.elegans')

heat_map_adjacency(Gcel0)



plt.subplot(4,3,2)

plt.title('(b) Airport')

heat_map_adjacency(Gair0)



plt.subplot(4,3,3)

plt.title('(c) US powergrid')

heat_map_adjacency(Gus0)


plt.subplot(4,3,4)

heat_map_adjacency(Gcel1)



plt.subplot(4,3,5)

heat_map_adjacency(Gair1)


plt.subplot(4,3,6)

heat_map_adjacency(Gus1)


plt.subplot(4,3,7)

heat_map_adjacency(Gcel2)


plt.subplot(4,3,8)

heat_map_adjacency(Gair2)


plt.subplot(4,3,9)

heat_map_adjacency(Gus2)

plt.subplot(4,3,10)

heat_map_adjacency(Gcel3)


plt.subplot(4,3,11)

heat_map_adjacency(Gair3)

plt.subplot(4,3,12)

heat_map_adjacency(Gus3)
