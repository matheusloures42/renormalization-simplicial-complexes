# %%
import networkx as nx
import numpy as np
import pandas as pd  
import os
import glob
from utils import *
from plot import *
from renormalizer import *
from kuramoto_plot import *
from simplicial_complexes import *

# %%
G0=nx.read_edgelist('../data/USpowergrid_n4941.txt',nodetype=int, data=(("Type", str),))
G0=nx.convert_node_labels_to_integers(G0)

# %%
G1=laplacian_renorm(G0,1)
G2=laplacian_renorm(G0,2)
G3=laplacian_renorm(G0,3)

# %%
print(Average_degree(G0))
print('\n')
print(Average_degree(G1))
print(Average_degree(G2))
print(Average_degree(G3))
# Out:
# 2.66909532483303
#
#
# 4.775394577094294
# 5.614886731391586
# 6.158576051779935

# %%
print(nx.average_clustering(G0))
print('\n')
print(nx.average_clustering(G1))
print(nx.average_clustering(G2))
print(nx.average_clustering(G3))
# Out:
# 0.08010361108159712
#
#
# 0.16377759117540577
# 0.23430778139516012
# 0.30564804244130317

# %%
G_list = [G0, G1, G2, G3]

for g in G_list:
    plot_distribution(g, plot_type="eigenvalue", fit_type="lognormal")

# %%
plot_degree_dist_power_law(G0,4)
plot_degree_dist_power_law(G1,5)
plot_degree_dist_power_law(G2,7)
plot_degree_dist_power_law(G3,9)
# Out:
# C:\Users\Costelinha\Documents\Codes\renormalization-simplicial-complexes\plot.py:289: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.xlim(xmin=0)
# gama=  3.5029791169846045   sigma=  0.0791907547362489
# C:\Users\Costelinha\Documents\Codes\renormalization-simplicial-complexes\plot.py:289: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.xlim(xmin=0)
# gama=  4.222471741006413   sigma=  0.09527437430908063
# C:\Users\Costelinha\Documents\Codes\renormalization-simplicial-complexes\plot.py:289: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.xlim(xmin=0)
# gama=  5.451903253966714   sigma=  0.24396279551118422
# C:\Users\Costelinha\Documents\Codes\renormalization-simplicial-complexes\plot.py:289: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.xlim(xmin=0)
# gama=  6.755236741785004   sigma=  0.590474830819651

# %%
G_list = [G0, G1, G2, G3]

for g in G_list:
    plot_distribution(g, plot_type="clustering coefficient", fit_type="lognormal")

# %%
plot_ccdf(G0,lb='l=0')
plot_ccdf(G1,lb='l=1')
plot_ccdf(G2,lb='l=2')
plot_ccdf(G3,lb='l=3')

# %%
clustering_per_kl(G0,lb='l=0')
clustering_per_kl(G1,lb='l=1')
clustering_per_kl(G2,lb='l=2')
clustering_per_kl(G3,lb='l=3')

# %%
eigenvector_centrality_x_kl(G0,lb='l=0')
eigenvector_centrality_x_kl(G1,lb='l=1')
eigenvector_centrality_x_kl(G2,lb='l=2')
eigenvector_centrality_x_kl(G3,lb='l=3')
# Out:
# ---------------------------------------------------------------------------
# PowerIterationFailedConvergence           Traceback (most recent call last)
# C:\Users\COSTEL~1\AppData\Local\Temp/ipykernel_16636/2933300934.py in <module>
#       1 eigenvector_centrality_x_kl(G0,lb='l=0')
#       2 eigenvector_centrality_x_kl(G1,lb='l=1')
# ----> 3 eigenvector_centrality_x_kl(G2,lb='l=2')
#       4 eigenvector_centrality_x_kl(G3,lb='l=3')
#
# ~\Documents\Codes\renormalization-simplicial-complexes\plot.py in eigenvector_centrality_x_kl(G, lb)
#     416     cpd=[]
#     417
# --> 418     centrality_coeff = nx.eigenvector_centrality(G)
#     419     values= list(centrality_coeff.values())
#     420
#
# ~\anaconda3\lib\site-packages\networkx\utils\decorators.py in argmap_eigenvector_centrality_18(G, max_iter, tol, nstart, weight)
#       2 from os.path import splitext
#       3 from contextlib import contextmanager
# ----> 4 from pathlib import Path
#       5 import warnings
#       6
#
# ~\anaconda3\lib\site-packages\networkx\algorithms\centrality\eigenvector.py in eigenvector_centrality(G, max_iter, tol, nstart, weight)
#     136         if sum(abs(x[n] - xlast[n]) for n in x) < nnodes * tol:
#     137             return x
# --> 138     raise nx.PowerIterationFailedConvergence(max_iter)
#     139
#     140
#
# PowerIterationFailedConvergence: (PowerIterationFailedConvergence(...), 'power iteration failed to converge within 100 iterations')
